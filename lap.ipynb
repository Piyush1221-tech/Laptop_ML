# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pickle

from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score,accuracy_score,mean_absolute_error

from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor

# %%
df = pd.read_csv("data.csv")

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Company', 'TypeName', 'Inches', 'ScreenResolution',
#        'Cpu', 'Ram', 'Memory', 'Gpu', 'OpSys', 'Weight', 'Price'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# ...

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df['Ram']= df['Ram'].str.replace('GB',' ')
df['Weight']=df['Weight'].str.replace('kg',' ')

# %%
df['Ram']=df['Ram'].astype('int32')
df['Weight']=df['Weight'].astype('float32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
# dtypes: float32(1), float64(2), int32(1), object(7)
# memory usage: 101.9+ KB

# %%
sns.barplot(x=df['Company'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df['Company'].value_counts().plot(kind='bar',figsize=(4,3))
# Out:
# <Axes: xlabel='Company'>

# %%
df['TypeName'].value_counts().plot(kind='bar',figsize=(4,3))
# Out:
# <Axes: xlabel='TypeName'>

# %%
df['Inches'].value_counts().plot(kind='bar',figsize=(4,3))
# Out:
# <Axes: xlabel='Inches'>

# %%
sns.barplot(x=df['Inches'],y= df['Price'])  # x = Inches, y = Price
plt.xticks(rotation='vertical')
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
# dtypes: float32(1), float64(2), int32(1), object(7)
# memory usage: 101.9+ KB

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232
# ...

# %%
sns.barplot(x=df['Ram'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.barplot(x=df['OpSys'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df['ScreenResolution'].value_counts()
# Out:
# ScreenResolution
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# ...

# %%
df['Touchscreen']=df['ScreenResolution'].apply(lambda x: 1 if ' Touchscreen' in x else 0 )

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0
# ...

# %%
df.sample(5)
# Out:
#      Company            TypeName  Inches                 ScreenResolution  \
# 109   Lenovo            Notebook    14.0      IPS Panel Full HD 1920x1080
# 22        HP            Notebook    15.6                         1366x768
# 1114  Lenovo  2 in 1 Convertible    10.1  IPS Panel Touchscreen 1920x1200
# 1102    Acer            Notebook    15.6                         1366x768
# 591   Lenovo            Notebook    15.6                Full HD 1920x1080
#
#                                        Cpu  Ram              Memory  \
# 109             Intel Core i7 7500U 2.7GHz    8           256GB SSD
# 22            AMD E-Series E2-9000e 1.5GHz    4           500GB HDD
# 1114           Intel Atom x5-Z8550 1.44GHz    4  64GB Flash Storage
# 1102  Intel Celeron Dual Core 3205U 1.5GHz    4            16GB SSD
# 591            AMD A12-Series 9720P 3.6GHz   12           512GB SSD
#
#                         Gpu       OpSys  Weight     Price  Touchscreen
# ...

# %%
df['Touchscreen'].value_counts().plot(kind='bar',figsize=(4,3))
# Out:
# <Axes: xlabel='Touchscreen'>

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['Touchscreen'],y=df['Price'])
plt.xticks(rotation='vertical')
figsize=(3,5)
plt.show()

# %%
df['Ips']=df['ScreenResolution'].apply(lambda x: 1 if 'IPS' in x else 0)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# ...

# %%
df['Ips'].value_counts().plot(kind='bar',figsize=(4,3))
# Out:
# <Axes: xlabel='Ips'>

# %%
sns.barplot(x=df['Ips'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
resulation =df['ScreenResolution'].str.split('x',n=1,expand=True)

# %%
df['x_res']=resulation[0]
df['y_res']=resulation[1].astype('int32')

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# ...

# %%
df['x_res'] = df['x_res'].str.replace(',','').str.findall(r'(\d+\.?\d+)').apply(lambda x:x[0]).astype('int')

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# ...

# %%
df.corr(numeric_only=True)['Price']
# Out:
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.192934
# Ips            0.252208
# x_res          0.556529
# y_res          0.552809
# Name: Price, dtype: float64

# %%
df['PPI']=((df['x_res']**2) + (df['y_res']**2))**0.5/df['Inches'].astype('float')

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# ...

# %%
df.drop(columns=['x_res','y_res','Inches'],inplace=True) # we calculate x_res ,y_res only for calculate ppi(pixekl per inchs)

# %%
df['Cpu'].value_counts()
# Out:
# Cpu
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core M M3-6Y30 0.9GHz        1
# AMD A9-Series 9420 2.9GHz          1
# Intel Core i3 6006U 2.2GHz         1
# AMD A6-Series 7310 2GHz            1
# Intel Xeon E3-1535M v6 3.1GHz      1
# Name: count, Length: 118, dtype: int64

# %%
df['Processor name']=df['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))

# %%
df.head()
# Out:
#   Company   TypeName                    ScreenResolution  \
# 0   Apple  Ultrabook  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook                            1440x900
# 2      HP   Notebook                   Full HD 1920x1080
# 3   Apple  Ultrabook  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# ...

# %%
def seprate_processor(text):
    if text=='Intel Core i7' or text =='Intel Core i5' or text=='Intel Core i3':
        return text
    else :
        if text.split()[0]=='Intel':
            return 'Another Processor'
        else:
            return 'Amd Processor'

# %%
df['Cpu brand'] = df['Processor name'].apply(seprate_processor)

# %%
df['Cpu brand'].value_counts().plot(kind='bar',figsize=(4,3))
# Out:
# <Axes: xlabel='Cpu brand'>

# %%
sns.barplot(x=df['Cpu brand'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df.drop(columns = ['Cpu','Processor name'] ,inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName                    ScreenResolution  Ram  \
# 0   Apple  Ultrabook  IPS Panel Retina Display 2560x1600    8
# 1   Apple  Ultrabook                            1440x900    8
# 2      HP   Notebook                   Full HD 1920x1080    8
# 3   Apple  Ultrabook  IPS Panel Retina Display 2880x1800   16
# 4   Apple  Ultrabook  IPS Panel Retina Display 2560x1600    8
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34
# 2            256GB SSD         Intel HD Graphics 620  No OS    1.86
# 3            512GB SSD            AMD Radeon Pro 455  macOS    1.83
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  Ips         PPI      Cpu brand
# 0   71378.6832            0    1  226.983005  Intel Core i5
# 1   47895.5232            0    0  127.677940  Intel Core i5
# ...

# %%
df['Memory'].value_counts()
# Out:
# Memory
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# ...

# %%
df.head()
# Out:
#   Company   TypeName                    ScreenResolution  Ram  \
# 0   Apple  Ultrabook  IPS Panel Retina Display 2560x1600    8
# 1   Apple  Ultrabook                            1440x900    8
# 2      HP   Notebook                   Full HD 1920x1080    8
# 3   Apple  Ultrabook  IPS Panel Retina Display 2880x1800   16
# 4   Apple  Ultrabook  IPS Panel Retina Display 2560x1600    8
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34
# 2            256GB SSD         Intel HD Graphics 620  No OS    1.86
# 3            512GB SSD            AMD Radeon Pro 455  macOS    1.83
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  Ips         PPI      Cpu brand
# 0   71378.6832            0    1  226.983005  Intel Core i5
# 1   47895.5232            0    0  127.677940  Intel Core i5
# ...

# %%
df['Memory']=df['Memory'].astype(str).replace('\.0','',regex=True)
df['Memory']=df['Memory'].str.replace('GB','')
df['Memory']=df['Memory'].str.replace('TB','000')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\.'
# <>:1: SyntaxWarning: invalid escape sequence '\.'
# C:\Users\piyus\AppData\Local\Temp\ipykernel_17820\3145258158.py:1: SyntaxWarning: invalid escape sequence '\.'
#   df['Memory']=df['Memory'].astype(str).replace('\.0','',regex=True)

# %%
new=df['Memory'].str.split("+",n=1,expand=True)
df['First']=new[0]
df['Second']=new[1]
df['Second'] = df['Second'].fillna("0")

# %%
df['L1HDD']=df['First'].apply(lambda x: 1 if "HDD" in x else 0)
df['L1SSD']=df['First'].apply(lambda x: 1 if "SSD" in x else 0)
df['L1Hybrid']=df['First'].apply(lambda x: 1 if "Hybrid" in x else 0)
df['L1Flash']=df['First'].apply(lambda x: 1 if "Flash Storage" in x else 0)

df['First'] = df['First'].str.replace(r'\D','', regex=True).str.strip()

# %%
df['Second']=df['Second'].fillna("0",inplace=True) # in second some laptop has no value after + (sign) so we fill these value with 0 because vlue is created 


df['L2HDD']=df['First'].apply(lambda x: 1 if "HDD" in x else 0)
df['L2SSD']=df['First'].apply(lambda x: 1 if "SSD" in x else 0)
df['L2Hybrid']=df['First'].apply(lambda x: 1 if "Hybrid" in x else 0)
df['L2Flash']=df['First'].apply(lambda x: 1 if "Flash Storage" in x else 0)

df['Second'] = df['Second'].str.replace(r'\D','', regex=True).str.strip()
# Out:
# C:\Users\piyus\AppData\Local\Temp\ipykernel_17820\714493256.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Second']=df['Second'].fillna("0",inplace=True) # in second some laptop has no value after + (sign) so we fill these value with 0 because vlue is created

# %%
df['First'] = df['First'].fillna('0').replace('', '0').astype(int)
df['Second'] = df['Second'].fillna('0').replace('', '0').astype(int)

# %%
df['SSD']=(df['First']*df['L1SSD']+df['Second']*df['L2SSD'])
df['HDD']=(df['First']*df['L1HDD']+df['Second']*df['L2HDD'])
df['Hybrid']=(df['First']*df['L1Hybrid']+df['Second']*df['L2Hybrid'])
df['Flash Memory']=(df['First']*df['L1Flash']+df['Second']*df['L2Flash'])

# %%
df.head()
# Out:
#   Company   TypeName                    ScreenResolution  Ram  \
# 0   Apple  Ultrabook  IPS Panel Retina Display 2560x1600    8
# 1   Apple  Ultrabook                            1440x900    8
# 2      HP   Notebook                   Full HD 1920x1080    8
# 3   Apple  Ultrabook  IPS Panel Retina Display 2880x1800   16
# 4   Apple  Ultrabook  IPS Panel Retina Display 2560x1600    8
#
#               Memory                           Gpu  OpSys  Weight  \
# 0            128 SSD  Intel Iris Plus Graphics 640  macOS    1.37
# 1  128 Flash Storage        Intel HD Graphics 6000  macOS    1.34
# 2            256 SSD         Intel HD Graphics 620  No OS    1.86
# 3            512 SSD            AMD Radeon Pro 455  macOS    1.83
# 4            256 SSD  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  ...  L1Hybrid  L1Flash L2HDD  L2SSD  L2Hybrid  \
# 0   71378.6832            0  ...         0        0     0      0         0
# ...

# %%
df.columns
# Out:
# Index(['Company', 'TypeName', 'ScreenResolution', 'Ram', 'Memory', 'Gpu',
#        'OpSys', 'Weight', 'Price', 'Touchscreen', 'Ips', 'PPI', 'Cpu brand',
#        'First', 'Second', 'L1HDD', 'L1SSD', 'L1Hybrid', 'L1Flash', 'L2HDD',
#        'L2SSD', 'L2Hybrid', 'L2Flash', 'SSD', 'HDD', 'Hybrid', 'Flash Memory'],
#       dtype='object')

# %%
df.drop(columns=['First', 'Second', 'L1HDD', 'L1SSD', 'L1Hybrid', 'L1Flash', 'L2HDD',
       'L2SSD', 'L2Hybrid', 'L2Flash'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName                    ScreenResolution  Ram  \
# 0   Apple  Ultrabook  IPS Panel Retina Display 2560x1600    8
# 1   Apple  Ultrabook                            1440x900    8
# 2      HP   Notebook                   Full HD 1920x1080    8
# 3   Apple  Ultrabook  IPS Panel Retina Display 2880x1800   16
# 4   Apple  Ultrabook  IPS Panel Retina Display 2560x1600    8
#
#               Memory                           Gpu  OpSys  Weight  \
# 0            128 SSD  Intel Iris Plus Graphics 640  macOS    1.37
# 1  128 Flash Storage        Intel HD Graphics 6000  macOS    1.34
# 2            256 SSD         Intel HD Graphics 620  No OS    1.86
# 3            512 SSD            AMD Radeon Pro 455  macOS    1.83
# 4            256 SSD  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  Ips         PPI      Cpu brand  SSD  HDD  Hybrid  \
# 0   71378.6832            0    1  226.983005  Intel Core i5  128    0       0
# ...

# %%
df.sample(5)
# Out:
#     Company   TypeName                           ScreenResolution  Ram  \
# 494    Asus     Gaming  IPS Panel Full HD / Touchscreen 1920x1080   24
# 435    Asus     Gaming                          Full HD 1920x1080    8
# 363      HP   Notebook                          Full HD 1920x1080    8
# 298  Lenovo   Notebook                          Full HD 1920x1080    6
# 802    Dell  Ultrabook                          Full HD 1920x1080    8
#
#                   Memory                      Gpu       OpSys  Weight  \
# 494  256 SSD +  1000 HDD  Nvidia GeForce GTX 965M  Windows 10    4.33
# 435  256 SSD +  1000 HDD        AMD Radeon RX 580  Windows 10    3.20
# 363             1000 HDD    Intel HD Graphics 620  Windows 10    1.86
# 298             1000 HDD        AMD Radeon R5 430  Windows 10    2.40
# 802              256 SSD    Intel HD Graphics 620  Windows 10    1.29
#
#         Price  Touchscreen  Ips         PPI      Cpu brand  SSD   HDD  Hybrid  \
# ...

# %%
df.drop(columns=['Memory'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName                    ScreenResolution  Ram  \
# 0   Apple  Ultrabook  IPS Panel Retina Display 2560x1600    8
# 1   Apple  Ultrabook                            1440x900    8
# 2      HP   Notebook                   Full HD 1920x1080    8
# 3   Apple  Ultrabook  IPS Panel Retina Display 2880x1800   16
# 4   Apple  Ultrabook  IPS Panel Retina Display 2560x1600    8
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           PPI      Cpu brand  SSD  HDD  Hybrid  Flash Memory
# 0  226.983005  Intel Core i5  128    0       0             0
# ...

# %%
df.corr(numeric_only=True)['Price']
# Out:
# Ram             0.743007
# Weight          0.210370
# Price           1.000000
# Touchscreen     0.192934
# Ips             0.252208
# PPI             0.473487
# SSD             0.676202
# HDD            -0.380428
# Hybrid         -0.040147
# Flash Memory   -0.040511
# Name: Price, dtype: float64

# %%
df.drop(columns=['Hybrid','Flash Memory'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName                    ScreenResolution  Ram  \
# 0   Apple  Ultrabook  IPS Panel Retina Display 2560x1600    8
# 1   Apple  Ultrabook                            1440x900    8
# 2      HP   Notebook                   Full HD 1920x1080    8
# 3   Apple  Ultrabook  IPS Panel Retina Display 2880x1800   16
# 4   Apple  Ultrabook  IPS Panel Retina Display 2560x1600    8
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           PPI      Cpu brand  SSD  HDD
# 0  226.983005  Intel Core i5  128    0
# 1  127.677940  Intel Core i5    0    0
# ...

# %%
df['Gpu'].value_counts()
# Out:
# Gpu
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# AMD Radeon 540               1
# ARM Mali T860 MP4            1
# Name: count, Length: 110, dtype: int64

# %%
df['GPU Brand']=df['Gpu'].apply(lambda x:x.split()[0])

# %%
df.head()
# Out:
#   Company   TypeName                    ScreenResolution  Ram  \
# 0   Apple  Ultrabook  IPS Panel Retina Display 2560x1600    8
# 1   Apple  Ultrabook                            1440x900    8
# 2      HP   Notebook                   Full HD 1920x1080    8
# 3   Apple  Ultrabook  IPS Panel Retina Display 2880x1800   16
# 4   Apple  Ultrabook  IPS Panel Retina Display 2560x1600    8
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           PPI      Cpu brand  SSD  HDD GPU Brand
# 0  226.983005  Intel Core i5  128    0     Intel
# ...

# %%
df['GPU Brand'].value_counts()
# Out:
# GPU Brand
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: count, dtype: int64

# %%
df=df[df['GPU Brand'] !='ARM']

# %%
df['GPU Brand'].value_counts()
# Out:
# GPU Brand
# Intel     722
# Nvidia    400
# AMD       180
# Name: count, dtype: int64

# %%
sns.barplot(x=df['GPU Brand'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df.drop(columns=['Gpu','ScreenResolution'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram  OpSys  Weight        Price  Touchscreen  Ips  \
# 0   Apple  Ultrabook    8  macOS    1.37   71378.6832            0    1
# 1   Apple  Ultrabook    8  macOS    1.34   47895.5232            0    0
# 2      HP   Notebook    8  No OS    1.86   30636.0000            0    0
# 3   Apple  Ultrabook   16  macOS    1.83  135195.3360            0    1
# 4   Apple  Ultrabook    8  macOS    1.37   96095.8080            0    1
#
#           PPI      Cpu brand  SSD  HDD GPU Brand
# 0  226.983005  Intel Core i5  128    0     Intel
# 1  127.677940  Intel Core i5    0    0     Intel
# 2  141.211998  Intel Core i5  256    0     Intel
# 3  220.534624  Intel Core i7  512    0       AMD
# 4  226.983005  Intel Core i5  256    0     Intel

# %%
df['OpSys'].value_counts()
# Out:
# OpSys
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: count, dtype: int64

# %%
sns.barplot(x=df['OpSys'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
def softwere(x):
    if x=='Windows 10 S' or x=='Windows 10' or x=='Windows 7' :
        return 'Windows'
    else:
        if x=='macOS' or x=='Mac OS X':
            return 'Mac'
        else:
            return 'Other/Linux'

# %%
df['OS']=df['OpSys'].apply(softwere)

# %%
df.head()
# Out:
#   Company   TypeName  Ram  OpSys  Weight        Price  Touchscreen  Ips  \
# 0   Apple  Ultrabook    8  macOS    1.37   71378.6832            0    1
# 1   Apple  Ultrabook    8  macOS    1.34   47895.5232            0    0
# 2      HP   Notebook    8  No OS    1.86   30636.0000            0    0
# 3   Apple  Ultrabook   16  macOS    1.83  135195.3360            0    1
# 4   Apple  Ultrabook    8  macOS    1.37   96095.8080            0    1
#
#           PPI      Cpu brand  SSD  HDD GPU Brand           OS
# 0  226.983005  Intel Core i5  128    0     Intel          Mac
# 1  127.677940  Intel Core i5    0    0     Intel          Mac
# 2  141.211998  Intel Core i5  256    0     Intel  Other/Linux
# 3  220.534624  Intel Core i7  512    0       AMD          Mac
# 4  226.983005  Intel Core i5  256    0     Intel          Mac

# %%
df.drop(columns=['OpSys'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram  Weight        Price  Touchscreen  Ips         PPI  \
# 0   Apple  Ultrabook    8    1.37   71378.6832            0    1  226.983005
# 1   Apple  Ultrabook    8    1.34   47895.5232            0    0  127.677940
# 2      HP   Notebook    8    1.86   30636.0000            0    0  141.211998
# 3   Apple  Ultrabook   16    1.83  135195.3360            0    1  220.534624
# 4   Apple  Ultrabook    8    1.37   96095.8080            0    1  226.983005
#
#        Cpu brand  SSD  HDD GPU Brand           OS
# 0  Intel Core i5  128    0     Intel          Mac
# 1  Intel Core i5    0    0     Intel          Mac
# 2  Intel Core i5  256    0     Intel  Other/Linux
# 3  Intel Core i7  512    0       AMD          Mac
# 4  Intel Core i5  256    0     Intel          Mac

# %%
sns.barplot(x=df['OS'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.distplot(df['Weight'])
# Out:
# C:\Users\piyus\AppData\Local\Temp\ipykernel_17820\1125578356.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Weight'])
# <Axes: xlabel='Weight', ylabel='Density'>

# %%
sns.distplot(np.log(df['Price']))
# Out:
# C:\Users\piyus\AppData\Local\Temp\ipykernel_17820\3556049916.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log(df['Price']))
# <Axes: xlabel='Price', ylabel='Density'>

# %%
X = df.drop(columns=['Price'])
y = np.log(df['Price'])

# %%
X
# Out:
#      Company            TypeName  Ram  Weight  Touchscreen  Ips         PPI  \
# 0      Apple           Ultrabook    8    1.37            0    1  226.983005
# 1      Apple           Ultrabook    8    1.34            0    0  127.677940
# 2         HP            Notebook    8    1.86            0    0  141.211998
# 3      Apple           Ultrabook   16    1.83            0    1  220.534624
# 4      Apple           Ultrabook    8    1.37            0    1  226.983005
# ...      ...                 ...  ...     ...          ...  ...         ...
# 1298  Lenovo  2 in 1 Convertible    4    1.80            1    1  157.350512
# 1299  Lenovo  2 in 1 Convertible   16    1.30            1    1  276.053530
# 1300  Lenovo            Notebook    2    1.50            0    0  111.935204
# 1301      HP            Notebook    6    2.19            0    0  100.454670
# 1302    Asus            Notebook    4    2.20            0    0  100.454670
#
# ...

# %%
y
# Out:
# 0       11.175755
# 1       10.776777
# 2       10.329931
# 3       11.814476
# 4       11.473101
#           ...
# 1298    10.433899
# 1299    11.288115
# 1300     9.409283
# 1301    10.614129
# 1302     9.886358
# Name: Price, Length: 1302, dtype: float64

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42)

# %%
X_train
# Out:
#      Company            TypeName  Ram  Weight  Touchscreen  Ips         PPI  \
# 1122      HP            Notebook    8    1.43            0    0  157.350512
# 438   Lenovo           Ultrabook   24    1.32            0    0  209.800683
# 579     Dell            Notebook    8    2.20            0    0  141.211998
# 842       HP            Notebook    8    2.63            0    0  106.113062
# 1161     MSI              Gaming   16    1.70            0    0  157.350512
# ...      ...                 ...  ...     ...          ...  ...         ...
# 1095    Acer            Notebook    8    2.40            0    0  141.211998
# 1130      HP            Notebook    8    2.04            0    0  100.454670
# 1295    Dell            Notebook    8    2.30            0    0  100.454670
# 860   Lenovo            Notebook    8    2.30            0    1  141.211998
# 1126  Lenovo  2 in 1 Convertible    4    0.69            1    1  224.173809
#
# ...

# %%
step1 = ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,7,10,11])],remainder='passthrough')

# %%
## Linear Regression

step2 = LinearRegression()

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)


print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))

mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100
accuracy = 100 - mape

print(f"Model Accuracy: {accuracy:.2f}%")
# Out:
# R2 score 0.7994763859918108
# MAE 0.21609614984665623
# Model Accuracy: 98.01%

# %%
## Ridge
step2 = Ridge(alpha=10)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))


mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100
accuracy = 100 - mape

print(f"Model Accuracy: {accuracy:.2f}%")
# Out:
# R2 score 0.7998146889713327
# MAE 0.2208521762112896
# Model Accuracy: 97.96%

# %%
## lesso 
step2 = Lasso(alpha=0.001)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100
accuracy = 100 - mape

print(f"Model Accuracy: {accuracy:.2f}%")
# Out:
# R2 score 0.8014557851713079
# MAE 0.21937971549964766
# Model Accuracy: 97.97%

# %%
## knn


step2 = KNeighborsRegressor(n_neighbors=3)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100
accuracy = 100 - mape

print(f"Model Accuracy: {accuracy:.2f}%")
# Out:
# R2 score 0.7530547767023319
# MAE 0.23505654901251405
# Model Accuracy: 97.83%

# %%
##  Desigen tree
step2 = DecisionTreeRegressor(max_depth=8)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100
accuracy = 100 - mape

print(f"Model Accuracy: {accuracy:.2f}%")
# Out:
# R2 score 0.8058558851035755
# MAE 0.21113702911837756
# Model Accuracy: 98.04%

# %%
## svm
step2 = SVR(kernel='rbf',C=10000,epsilon=0.1)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100
accuracy = 100 - mape

print(f"Model Accuracy: {accuracy:.2f}%")
# Out:
# R2 score 0.8251268925390804
# MAE 0.20178069680160107
# Model Accuracy: 98.14%

# %%
## randomm forest
step2 = RandomForestRegressor(n_estimators=100,
                              random_state=3,
                              max_samples=0.5,
                              max_features=0.75,
                              max_depth=15)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100
accuracy = 100 - mape

print(f"Model Accuracy: {accuracy:.2f}%")
# Out:
# R2 score 0.8675020230193939
# MAE 0.1731321037935419
# Model Accuracy: 98.40%

# %%
## xgboost
step2 = XGBRegressor(n_estimators=45,max_depth=5,learning_rate=0.5)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100
accuracy = 100 - mape

print(f"Model Accuracy: {accuracy:.2f}%")
# Out:
# R2 score 0.8601164866098123
# MAE 0.17605306577098864
# Model Accuracy: 98.38%

# %%
## adboost
step2 = AdaBoostRegressor(n_estimators=15,learning_rate=1.0)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100
accuracy = 100 - mape

print(f"Model Accuracy: {accuracy:.2f}%")
# Out:
# R2 score 0.7928962679688605
# MAE 0.2327675403541274
# Model Accuracy: 97.84%

# %%
## gradient boost
step2 = GradientBoostingRegressor(n_estimators=500)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100
accuracy = 100 - mape

print(f"Model Accuracy: {accuracy:.2f}%")
# Out:
# R2 score 0.8750950206914258
# MAE 0.1660318346819455
# Model Accuracy: 98.47%

# %% [markdown]
# ## Exporting the model

# %%
## we write this code on below the best modle code
## kyoki yeh code jis model ke neeche likha hoga usi ka pickle file banayegaa
## is code me yah gradient boost ka pickle banayegaa
pickle.dump(pipe,open('model.pkl','wb'))
pickle.dump(df,open('df.pkl','wb'))
